# %% [markdown]
# **This notebook is maily for the Capstone Project Course1

# %%
import pandas as pd

# %%
pip install numpy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np

# %%
print("Hello Capstone Project Course!")
# Out:
# Hello Capstone Project Course!
